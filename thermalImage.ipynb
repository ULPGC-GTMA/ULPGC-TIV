# %%
from PIL import Image

print(type(Image)) # Objeto de clase module
# Out:
# <class 'module'>

# %%
file = 'images/0_T__2023-07-07_14-38-20-165401.tiff'
print(type(file))
print(id(file))

img  = Image.open(file)
print(type(img))
print(id(img))
# Out:
# <class 'str'>
# 1581001031472
# <class 'PIL.TiffImagePlugin.TiffImageFile'>
# 1581001245200

# %%
print('formato:', img.format)
print('(ancho, alto) =', img.size)
print('modo: ', img.mode)
# Out:
# formato: TIFF
# (ancho, alto) = (384, 288)
# modo:  F

# %%
from PIL import ImageShow

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.imshow(img)

# %%
img_np = np.array(img)

# %%
plt.imshow(img_np, cmap='inferno')
plt.colorbar()
